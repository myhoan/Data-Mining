# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from pandas.plotting import scatter_matrix
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("D:/Study/2021-2022 _ HK2/MKTG5883_DataMiningApp/Lab2/job-market.csv")
df
# Out:
#                Id                                              Title  \
# 0      37404348.0                           Casual Stock Replenisher
# 1      37404337.0                           Casual Stock Replenisher
# 2      37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3      37404330.0                              Team member - Belrose
# 4      37404308.0  Business Banking Contact Centre Specialist, Ni...
# ...           ...                                                ...
# 40784         NaN                                                NaN
# 40785         NaN                                                NaN
# 40786         NaN                                                NaN
# 40787         NaN                                                NaN
# 40788         NaN                                                NaN
#
#                                               Company  \
# 0                                         Aldi Stores
# ...

# %%
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
df.dtypes
# Out:
# Id                   float64
# Title                 object
# Company               object
# Date                  object
# Location              object
# Area                  object
# Classification        object
# SubClassification     object
# Requirement           object
# FullDescription       object
# LowestSalary         float64
# HighestSalary        float64
# JobType               object
# dtype: object

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Id                               float64
# Title                             object
# Company                           object
# Date                 datetime64[ns, UTC]
# Location                          object
# Area                              object
# Classification                    object
# SubClassification                 object
# Requirement                       object
# FullDescription                   object
# LowestSalary                     float64
# HighestSalary                    float64
# JobType                           object
# dtype: object

# %%
df[df.duplicated()].shape[0]
# Out:
# 30689

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()].shape[0]
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Id                      1
# Title                   1
# Company               617
# Date                    1
# Location                1
# Area                 3708
# Classification          1
# SubClassification       1
# Requirement             1
# FullDescription       257
# LowestSalary            1
# HighestSalary           1
# JobType               248
# dtype: int64

# %%
df.dropna(inplace = True)
df
# Out:
#                Id                                         Title  \
# 121    37404238.0                          Fabricator/Installer
# 122    37404195.0                                   Boilermaker
# 125    37404288.0  Casual Childcare Positions  | Bondi Junction
# 126    37404267.0                                    Technician
# 127    37404230.0                              Systems Engineer
# ...           ...                                           ...
# 10091  37388929.0                            Lead Kit Assembler
# 10094  37388912.0                           Executive Assistant
# 10096  37388901.0                  Receptionist / Administrator
# 10097  37388898.0     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893.0               Customer Service Representative
#
#                            Company                      Date   Location  \
# 121      WORKPLACE ACCESS & SAFETY 2018-10-07 00:00:00+00:00  Melbourne
# ...

# %%
df.isnull().sum()
# Out:
# Id                   0
# Title                0
# Company              0
# Date                 0
# Location             0
# Area                 0
# Classification       0
# SubClassification    0
# Requirement          0
# FullDescription      0
# LowestSalary         0
# HighestSalary        0
# JobType              0
# dtype: int64

# %%
df['Id']= pd.to_numeric(df['Id'], downcast='signed')

# %%
df.dtypes
# Out:
# Id                                 int32
# Title                             object
# Company                           object
# Date                 datetime64[ns, UTC]
# Location                          object
# Area                              object
# Classification                    object
# SubClassification                 object
# Requirement                       object
# FullDescription                   object
# LowestSalary                     float64
# HighestSalary                    float64
# JobType                           object
# dtype: object

# %%
# s = pd.Series(['1.0', '2', -3])
# pd.to_numeric(s)
# 0    1.0
# 1    2.0
# 2   -3.0
# dtype: float64
# pd.to_numeric(s, downcast='float')
# 0    1.0
# 1    2.0
# 2   -3.0
# dtype: float32
# pd.to_numeric(s, downcast='signed')
# 0    1
# 1    2
# 2   -3
# dtype: int8
# s = pd.Series(['apple', '1.0', '2', -3])
# pd.to_numeric(s, errors='ignore')
# 0    apple
# 1      1.0
# 2        2
# 3       -3
# dtype: object
# pd.to_numeric(s, errors='coerce')
# 0    NaN
# 1    1.0
# 2    2.0
# 3   -3.0
# dtype: float64

# %%
df
# Out:
#              Id                                         Title  \
# 121    37404238                          Fabricator/Installer
# 122    37404195                                   Boilermaker
# 125    37404288  Casual Childcare Positions  | Bondi Junction
# 126    37404267                                    Technician
# 127    37404230                              Systems Engineer
# ...         ...                                           ...
# 10091  37388929                            Lead Kit Assembler
# 10094  37388912                           Executive Assistant
# 10096  37388901                  Receptionist / Administrator
# 10097  37388898     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893               Customer Service Representative
#
#                            Company                      Date   Location  \
# 121      WORKPLACE ACCESS & SAFETY 2018-10-07 00:00:00+00:00  Melbourne
# 122        RPM Contracting QLD P/l 2018-10-07 00:00:00+00:00   Brisbane
# ...

# %%
df['Id'].is_unique
# Out:
# True

# %%
df = df.set_index('Id')

# %%
df.head()
# Out:
#                                                  Title  \
# Id
# 37404238                          Fabricator/Installer
# 37404195                                   Boilermaker
# 37404288  Casual Childcare Positions  | Bondi Junction
# 37404267                                    Technician
# 37404230                              Systems Engineer
#
#                               Company                      Date   Location  \
# Id
# 37404238    WORKPLACE ACCESS & SAFETY 2018-10-07 00:00:00+00:00  Melbourne
# 37404195      RPM Contracting QLD P/l 2018-10-07 00:00:00+00:00   Brisbane
# 37404288              anzuk Education 2018-10-07 00:00:00+00:00     Sydney
# 37404267  Zoom Recruitment & Training 2018-10-07 00:00:00+00:00     Sydney
# 37404230              Humanised Group 2018-10-07 00:00:00+00:00   Brisbane
#
#                                        Area  \
# Id
# 37404238    Bayside & South Eastern Suburbs
# 37404195           Southern Suburbs & Logan
# ...

# %% [markdown]
# # Lab3

# %%
df
# Out:
#                                                  Title  \
# Id
# 37404238                          Fabricator/Installer
# 37404195                                   Boilermaker
# 37404288  Casual Childcare Positions  | Bondi Junction
# 37404267                                    Technician
# 37404230                              Systems Engineer
# ...                                                ...
# 37388929                            Lead Kit Assembler
# 37388912                           Executive Assistant
# 37388901                  Receptionist / Administrator
# 37388898     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 37388893               Customer Service Representative
#
#                               Company                      Date   Location  \
# Id
# 37404238    WORKPLACE ACCESS & SAFETY 2018-10-07 00:00:00+00:00  Melbourne
# 37404195      RPM Contracting QLD P/l 2018-10-07 00:00:00+00:00   Brisbane
# ...

# %%
df['Location']
# Out:
# 121      Melbourne
# 122       Brisbane
# 125         Sydney
# 126         Sydney
# 127       Brisbane
#            ...
# 10091    Melbourne
# 10094    Melbourne
# 10096     Brisbane
# 10097     Brisbane
# 10098       Sydney
# Name: Location, Length: 5898, dtype: object

# %%
df.isnull().sum()
# Out:
# Id                   0
# Title                0
# Company              0
# Date                 0
# Location             0
# Area                 0
# Classification       0
# SubClassification    0
# Requirement          0
# FullDescription      0
# LowestSalary         0
# HighestSalary        0
# JobType              0
# dtype: int64

# %%
df['NumberOfJob'] = 1

# %%
df
# Out:
#              Id                                         Title  \
# 121    37404238                          Fabricator/Installer
# 122    37404195                                   Boilermaker
# 125    37404288  Casual Childcare Positions  | Bondi Junction
# 126    37404267                                    Technician
# 127    37404230                              Systems Engineer
# ...         ...                                           ...
# 10091  37388929                            Lead Kit Assembler
# 10094  37388912                           Executive Assistant
# 10096  37388901                  Receptionist / Administrator
# 10097  37388898     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893               Customer Service Representative
#
#                            Company                      Date   Location  \
# 121      WORKPLACE ACCESS & SAFETY 2018-10-07 00:00:00+00:00  Melbourne
# 122        RPM Contracting QLD P/l 2018-10-07 00:00:00+00:00   Brisbane
# ...

# %%
CountnumberTable = pd.pivot_table(data=df, index=['Location'], aggfunc={'NumberOfJob': np.sum}).sort_values(by='NumberOfJob',ascending=False).reset_index()

# %%
CountnumberTable
# Out:
#     Location  NumberOfJob
# 0     Sydney         2382
# 1  Melbourne         2094
# 2   Brisbane          900
# 3      Perth          522
